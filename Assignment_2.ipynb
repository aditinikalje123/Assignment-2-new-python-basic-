# %% [markdown]
# # Data type and structure question (theory questions)
# 1) What are data structures, and why are they important
#
# Ans:-A way of organizing and storing data so that it can be accessed and manipulated efficiently. They are important as they help to access and organize data management, allow programs to run fast and give optimized output with improved code readability.
#
# 2) Explain the difference between mutable and immutable data types with examples
#
# Ans:-Mutable datatype:- can be edited after creation. eg, list
# immutable datatype :-cannot be edited after creation. eg, tuples
#
# 3)What are the main differences between lists and tuples in Python
#
# Ans:- The main difference is that list are mutable whereas tuples are immutable.
#
# 4)Describe how dictionaries store data
#
# Ans:-They store the data in the form of key value pair. d={"key","value"}
#
# 5)Why might you use a set instead of a list in Python
#
# Ans:-Because sets are unordered and give unique collection of elements as output that is they does not allow duplicate elements.
#
# 6)What is a string in Python, and how is it different from a list
#
# Ans:-string is a sequence of characters that represent and manipulate texual data. eg,a="aditi"
# string contains characters whereas list contain anytype of data.
#
# 7)How do tuples ensure data integrity in Python
#
# Ans:-Tuples ensure data integrity in Python because they are immutable, meaning their contents cannot be altered after creation, thus preventing accidental or unintended modifications.
#
# 8)What is a hash table, and how does it relate to dictionaries in Python
#
# Ans:-A hash table is a data structure that offers an efficient way to organize data for quick access.Python dictionaries are implemented using hash tables, which provide efficient key-based data storage and retrieval with average-case O(1) time complexity for common operations.
#
# 9)Can lists contain different data types in Python
#
# Ans:-yes
#
# 10)Explain why strings are immutable in Python
#
# Ans:-Strings are immutable in Python to allow for optimizations like string interning and to ensure data integrity, as it prevents unintentional modification when multiple variables reference the same string.
#
# 11)What advantages do dictionaries offer over lists for certain tasks
#
# Ans:-In dictionary keys are unique and immutable, dictionaries provide faster lookups compared to lists when searching by key, as they have an average complexity of O(1), while lists require O(n) in the worst case.
#
# 12)Describe a scenario where using a tuple would be preferable over a list
#
# Ans:-aadhar card id,atm pin,emp_id in these cases we prefer using tuple instead of strings as tuples are immmutable .
#
# 13)How do sets handle duplicate values in Python
#
# Ans:-If perticular value is present more than one time then in output set gives only one time as sets return unique value.
#
# 14)How does the “in” keyword work differently for lists and dictionaries
#
# Ans:-for list:- if the specific value is present in list or not
#     for dictionaries:- if a key exists in dictionary or not
#
# 15)Can you modify the elements of a tuple? Explain why or why not
#
# Ans:-we cannot modify the elements in tuple because tuples are immutable.
#
# 16)What is a nested dictionary, and give an example of its use case
#
# Ans:-a nested dictionary is a dictionary where one or more than one values are themselves dictionaries,
# use case:- to group related data ,to represent real world objects with multiple attribute.
#
# 17)Describe the time complexity of accessing elements in a dictionary
#
# Ans:-O(1)
#
# 18)In what situations are lists preferred over dictionaries
#
# Ans:-  Ordered collection
# Positional access or slicing
# Simple sequence of values
# Duplicate elements allowed
# Fast iteration
#
# 19)Why are dictionaries considered unordered, and how does that affect data retrieval
#
# Ans:-dictionaries are unordered but after python 3.7 version dictionaries return order of insertion.
#
# 20) Explain the difference between a list and a dictionary in terms of data retrieval.
#
# Ans:-In list elements are retrived by index and in dictionary elements are retrieved by key.(retrived=access the element)

# %% [markdown]
# PRACTICAL QUESTIONS (CODEING)

# %% [markdown]
# 1)Write a code to create a string with your name and print it

# %%
my_name="aditi"
print("My name is :-",my_name)
# Out:
# My name is :- aditi

# %% [markdown]
# 2) Write a code to find the length of the string "Hello World"

# %%
len("Hello World")
# Out:
# 11

# %% [markdown]
# 3) Write a code to slice the first 3 characters from the string "Python Programming

# %%
a="Python Programming"
slice_a= a[0:3]
print("first 3 characters are:",slice_a)
# Out:
# first 3 characters are: Pyt

# %% [markdown]
# 4) Write a code to convert the string "hello" to uppercase

# %%
a = "hello"
uppercase_a = a.upper()
print("upper_case:",uppercase_a)
# Out:
# upper_case: HELLO

# %% [markdown]
# 5)Write a code to replace the word "apple" with "orange" in the string "I like apple"

# %%
string = "I like Apple"
a = string.replace("Apple","Orange")
print("updated string is:",a)
# Out:
# updated string is: I like Orange

# %% [markdown]
# 6)Write a code to create a list with numbers 1 to 5 and print it

# %%
list = [1,2,3,4,5]
list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 7) Write a code to append the number 10 to the list [1, 2, 3, 4]

# %%
list = [1,2,3,4]
list.append(10)
list
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 8) Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]

# %%
list = [1,2,3,4,5]
list.remove(3)
list
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9)Write a code to access the second element in the list ['a', 'b', 'c', 'd']

# %%
list = ['a','b','c','d']
list[1]
# Out:
# 'b'

# %% [markdown]
# 10)Write a code to reverse the list [10, 20, 30, 40, 50]

# %%
list = [10,20,30,40,50]
list.reverse()
list
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# 11) Write a code to create a tuple with the elements 100, 200, 300 and print it

# %%
tuple = (100,200,300)
tuple
# Out:
# (100, 200, 300)

# %% [markdown]
# 12) Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

# %%
tuple = ("red","green","blue","yellow")
tuple[-2]
# Out:
# 'blue'

# %% [markdown]
# 13)Write a code to find the minimum number in the tuple (10, 20, 5, 15).

# %%
tuple1= (10,20,5,15)
min_number = min(tuple1)
print("min number is :",min_number)
# Out:
# min number is : 5

# %% [markdown]
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')

# %%
tuple = ("dog","cat","rabbit")
index_cat = tuple.index("cat")
print("index is:",index_cat)
# Out:
# index is: 1

# %% [markdown]
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it

# %%
fruits = ("apple","grapes","kiwi")
"kiwi" in fruits
# Out:
# True

# %% [markdown]
# 16. Write a code to create a set with the elements 'a', 'b', 'c' and print it

# %%
set = {"a","b","c"}
set
# Out:
# {'a', 'b', 'c'}

# %% [markdown]
# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

# %%
set = {1,2,3,4,5}
set .clear()
set
# Out:
# set()

# %% [markdown]
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

# %%
set = {1,2,3,4}
set.remove(4)
set
# Out:
# {1, 2, 3}

# %% [markdown]
# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

# %%
a = {1,2,3}
b ={3,4,5}
a|b
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.

# %%
a = {1,2,3}
b = {2,3,4}
a.intersection(b)
# Out:
# {2, 3}

# %% [markdown]
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

# %%
dict = {"name":"aditi","age":"21","city":"amravati"}
dict
# Out:
# {'name': 'aditi', 'age': '21', 'city': 'amravati'}

# %% [markdown]
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}

# %%
dict = {"name":"john","age":"25"}
dict["country"] = "USA"
dict
# Out:
# {'name': 'john', 'age': '25', 'country': 'USA'}

# %% [markdown]
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

# %%
dict = {"name":"alice","age":"30"}
name_value = dict["name"]
print("value of name key is",name_value)
# Out:
# value of name key is alice

# %% [markdown]
# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

# %%
dict = {"name": "Bob", "age": 22, "city": "New York"}
dict.pop('age')
# Out:
# 22

# %% [markdown]
# 25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

# %%
dist = {"name": "Alice", "city": "Paris"}
"city" in dist
# Out:
# True

# %% [markdown]
# 26. Write a code to create a list, a tuple, and a dictionary, and print them al

# %%
my_list = [1,2,3,"aditi"]
my_tuple = {"pwskills",3,5,8,2.7}
my_dict = {"name":"aditi","age":"21"}
print("list:", my_list)
print("tuple:", my_tuple)
print("dict:", my_dict)
# Out:
# list: [1, 2, 3, 'aditi']
# tuple: {2.7, 3, 5, 8, 'pwskills'}
# dict: {'name': 'aditi', 'age': '21'}

# %% [markdown]
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
# result.(replaced)

# %%
import random
random_numbers = random.sample(range(1, 101), 5)
random_numbers.sort()
print("Sorted random numbers:", random_numbers)
# Out:
# Sorted random numbers: [10, 26, 52, 76, 82]

# %% [markdown]
# 28. Write a code to create a list with strings and print the element at the third index.

# %%
list = ["aditi","neha","janvi","urfi"]
index_th = list[3]
print("element at third index is:",index_th)
# Out:
# element at third index is: urfi

# %% [markdown]
# 29. Write a code to combine two dictionaries into one and print the result.

# %%
dict = {"name":"aditi","age":"21"}
Dict={"class":"third year"}
combined_dict = {**dict, **Dict}
combined_dict
# Out:
# {'name': 'aditi', 'age': '21', 'class': 'third year'}

# %% [markdown]
# 30. Write a code to convert a list of strings into a set.

# %%
employee_list = ["John", "Emma", "Michael", "Emily", "John", "David"]
# Use a different variable name, like 'employee_set' to avoid conflict with built-in function 'set'
employee_set = set(employee_list)
print(employee_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-ca0cca4ee4f3> in <cell line: 0>()
#       1 employee_list = ["John", "Emma", "Michael", "Emily", "John", "David"]
#       2 # Use a different variable name, like 'employee_set' to avoid conflict with built-in function 'set'
# ----> 3 employee_set = set(employee_list)
#       4 print(employee_set)
#
# TypeError: 'set' object is not callable
